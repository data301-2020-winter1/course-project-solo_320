# %%
import pandas as pd
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from scripts.project_functions import load_and_process
df = load_and_process("../data/raw/winequality-red.csv","../data/raw/winequality-white.csv")
df
# Out:
#        wine_type  citric acid  fixed acidity  volatile acidity  \
# 0       red wine         0.22            6.8              0.56
# 1     white wine         0.36            6.4              0.30
# 2     white wine         0.29            5.9              0.17
# 3     white wine         0.24            7.0              0.24
# 4     white wine         0.07            6.4              0.45
# ...          ...          ...            ...               ...
# 6492    red wine         0.45           12.7              0.59
# 6493  white wine         0.35            8.0              0.25
# 6494    red wine         0.14            8.3              0.85
# 6495    red wine         0.10            6.3              0.60
# 6496  white wine         0.49            7.1              0.18
#
#       residual sugar  chlorides  sulphates  free sulfur dioxide  \
# 0                1.8      0.074       0.82                 15.0
# 1                2.0      0.052       0.53                 18.0
# 2                3.1      0.030       0.33                 32.0
# 3                1.8      0.047       0.43                 29.0
# 4                1.1      0.030       0.28                 10.0
# ...              ...        ...        ...                  ...
# 6492             2.3      0.082       0.70                 11.0
# 6493             1.1      0.054       0.55                 13.0
# 6494             2.5      0.093       0.54                 13.0
# 6495             1.6      0.048       0.51                 12.0
# 6496             1.3      0.033       0.53                 12.0
#
#       total sulfur dioxide  density    pH  alcohol  quality   quality_label
# 0                     24.0  0.99438  3.40     11.2        6  medium quality
# 1                    141.0  0.99273  3.38     10.5        6  medium quality
# 2                    123.0  0.98913  3.41     13.7        7  medium quality
# 3                     91.0  0.99251  3.30      9.9        6  medium quality
# 4                    131.0  0.99050  2.97     10.8        5     low quality
# ...                    ...      ...   ...      ...      ...             ...
# 6492                  22.0  1.00000  3.00      9.3        6  medium quality
# 6493                 136.0  0.99366  3.08      9.5        5     low quality
# 6494                  54.0  0.99724  3.36     10.1        5     low quality
# 6495                  26.0  0.99306  3.55     12.1        5     low quality
# 6496                  72.0  0.99072  3.05     11.3        7  medium quality
#
# [5320 rows x 14 columns]

# %%
os.getcwd()
# Out:
# '/Users/shreeta/Data301/project/course-project-solo_320/analysis'

# %%
df.to_csv(r'/Users/shreeta/Data301/project/course-project-solo_320/data/processed/tableau_dataset.csv', index = False, header = True)
